# %%
import json

nlp_trend_report = {
    "dataset_overview": {
        "total_patents": 667,
        "start_date": "2014-12-05",
        "end_date": "2022-12-15",
        "analysis_years": [2016, 2017, 2018, 2019, 2020, 2021, 2022],
        "num_periods": 7
    },
    "meaningful_terms_analysis": {
        "total_terms": 6199,
        "unique_terms": 4701,
        "avg_terms_per_patent": 9.29
    },
    "top_trending_terms": [
        {"term": "computer memory", "r": 0.916, "p": 0.004},
        {"term": "training data", "r": 0.867, "p": 0.012},
        {"term": "deep learning operations", "r": 0.851, "p": 0.015},
        {"term": "wireless communication", "r": 0.846, "p": 0.016},
        {"term": "state information", "r": 0.830, "p": 0.021},
        {"term": "cloud computing resources", "r": 0.800, "p": 0.031},
        {"term": "encoder decoder", "r": 0.790, "p": 0.035},
        {"term": "user interface", "r": 0.781, "p": 0.038}
    ],
    "top_declining_terms": [
        {"term": "storage media", "r": -0.909, "p": 0.005},
        {"term": "decision making", "r": -0.883, "p": 0.008},
        {"term": "object recognition", "r": -0.844, "p": 0.017},
        {"term": "computer storage", "r": -0.840, "p": 0.018},
        {"term": "computer storage media", "r": -0.840, "p": 0.018},
        {"term": "convolutional neural", "r": -0.833, "p": 0.020},
        {"term": "reinforcement learning", "r": -0.822, "p": 0.023},
        {"term": "medium storage", "r": -0.814, "p": 0.026},
        {"term": "training comprises", "r": -0.743, "p": 0.056},
        {"term": "object classification", "r": -0.743, "p": 0.056},
        {"term": "sensor data", "r": -0.680, "p": 0.093},
        {"term": "observation action", "r": -0.676, "p": 0.095}
    ],
    "most_frequent_terms": [
        {"term": "machine learning", "count": 147, "per_patent": 0.220},
        {"term": "convolutional neural", "count": 64, "per_patent": 0.096},
        {"term": "medium storage", "count": 40, "per_patent": 0.060},
        {"term": "storage medium", "count": 39, "per_patent": 0.058},
        {"term": "training data", "count": 31, "per_patent": 0.046},
        {"term": "loss function", "count": 29, "per_patent": 0.043},
        {"term": "deep learning", "count": 28, "per_patent": 0.042},
        {"term": "storage media", "count": 26, "per_patent": 0.039},
        {"term": "sensor data", "count": 26, "per_patent": 0.039},
        {"term": "cloud computing resources", "count": 22, "per_patent": 0.033},
        {"term": "wireless communication", "count": 20, "per_patent": 0.030},
        {"term": "reinforcement learning", "count": 18, "per_patent": 0.027},
        {"term": "recurrent neural", "count": 18, "per_patent": 0.027},
        {"term": "object detection", "count": 17, "per_patent": 0.025},
        {"term": "executable computer", "count": 16, "per_patent": 0.024}
    ],
    "domain_trends": {
        "AI/ML for AVs": {"num_trending_terms": 1, "avg_correlation": 0.790},
        "Human-Machine Interface": {"num_trending_terms": 1, "avg_correlation": 0.781}
    },
    "technology_shift": {
        "2021_to_2022_similarity": 0.927
    },
    "top_applicant_focus": [
        {
            "applicant": "INTEL CORP",
            "num_patents": 140,
            "focus": ["machine learning", "collaborative semantic mapping", "memory map"]
        },
        {
            "applicant": "NVIDIA CORP",
            "num_patents": 128,
            "focus": ["encryption standard", "operation descriptor", "circuit asic"]
        },
        {
            "applicant": "FORD GLOBAL TECH LLC",
            "num_patents": 90,
            "focus": ["machine learning", "computer memory", "strain displacement"]
        },
        {
            "applicant": "QUALCOMM INC",
            "num_patents": 79,
            "focus": ["output mask", "segmentation neural", "coordinate information"]
        },
        {
            "applicant": "TOYOTA RES INST INC",
            "num_patents": 55,
            "focus": ["odometry noise model", "motion sensor", "fleet-scale datasets"]
        }
    ]
}

# Save to JSON file
with open("nlp_trend_report.json", "w", encoding="utf-8") as f:
    json.dump(nlp_trend_report, f, indent=4)

print("NLP trend report saved to nlp_trend_report.json")
# Out:
# NLP trend report saved to nlp_trend_report.json

# %%
import json

semantic_clustering_report = {
    "report_title": "Semantic Patent Clustering Report",
    "clustering_overview": {
        "total_clusters": 6,
        "cluster_ids": [0, 1, 2, 3, 4, 5],
        "total_patents_clustered": 667,
        "unique_applicants_across_clusters": 14
    },
    "clusters": [
        {
            "cluster_id": 0,
            "semantic_coherence": 0.470,
            "size": 43,
            "key_concepts": ["wireless", "ue", "csi", "apparatus", "channel", "signal", "information"],
            "timeline": {
                "start_date": "2018-04-05",
                "end_date": "2021-12-06"
            },
            "unique_applicants": 6,
            "leading_applicants": [
                {"name": "QUALCOMM INC", "patents": 31, "percentage": 72.1},
                {"name": "INTEL CORP", "patents": 7, "percentage": 16.3},
                {"name": "GOOGLE LLC", "patents": 2, "percentage": 4.7},
                {"name": "TOYOTA MOTOR CO LTD", "patents": 1, "percentage": 2.3},
                {"name": "FORD GLOBAL TECH LLC", "patents": 1, "percentage": 2.3}
            ],
            "market_concentration": {
                "level": "High",
                "hhi": 0.549
            },
            "top_cpc_symbols": [
                {"symbol": "G06N20/00", "count": 27},
                {"symbol": "G06N3/08", "count": 18},
                {"symbol": "G06N3/045", "count": 18}
            ],
            "example_patents": [
                "Vehicle-to-everything data transfer for automated vehicles",
                "Systems and methods for optimizing an antenna topology of a vehicle"
            ]
        },
        {
            "cluster_id": 1,
            "semantic_coherence": 0.454,
            "size": 90,
            "key_concepts": ["image", "depth", "images", "3d", "object", "data", "camera"],
            "timeline": {
                "start_date": "2016-09-09",
                "end_date": "2022-11-30"
            },
            "unique_applicants": 12,
            "leading_applicants": [
                {"name": "NVIDIA CORP", "patents": 38, "percentage": 42.2},
                {"name": "QUALCOMM INC", "patents": 11, "percentage": 12.2},
                {"name": "FORD GLOBAL TECH LLC", "patents": 10, "percentage": 11.1},
                {"name": "TOYOTA RES INST INC", "patents": 8, "percentage": 8.9},
                {"name": "INTEL CORP", "patents": 6, "percentage": 6.7}
            ],
            "market_concentration": {
                "level": "Medium",
                "hhi": 0.218
            },
            "top_cpc_symbols": [
                {"symbol": "G06N3/045", "count": 65},
                {"symbol": "G06N3/08", "count": 56},
                {"symbol": "G06T2207/20084", "count": 38}
            ],
            "example_patents": [
                "Unsupervised learning of image depth and ego-motion prediction neural networks",
                "Systems and methods for camera-LiDAR fused object detection with local variation segmentation"
            ]
        },
        {
            "cluster_id": 2,
            "semantic_coherence": 0.435,
            "size": 99,
            "key_concepts": ["neural", "network", "neural network", "data", "layer", "image", "plurality"],
            "timeline": {
                "start_date": "2016-07-28",
                "end_date": "2022-07-15"
            },
            "unique_applicants": 13,
            "leading_applicants": [
                {"name": "NVIDIA CORP", "patents": 28, "percentage": 28.3},
                {"name": "INTEL CORP", "patents": 21, "percentage": 21.2},
                {"name": "QUALCOMM INC", "patents": 20, "percentage": 20.2},
                {"name": "GOOGLE LLC", "patents": 8, "percentage": 8.1},
                {"name": "AMAZON TECH INC", "patents": 5, "percentage": 5.1}
            ],
            "market_concentration": {
                "level": "Medium",
                "hhi": 0.175
            },
            "top_cpc_symbols": [
                {"symbol": "G06N3/045", "count": 93},
                {"symbol": "G06N3/08", "count": 53},
                {"symbol": "G06N3/084", "count": 53}
            ],
            "example_patents": [
                "Machine-learning-based architecture search method for a neural network",
                "Tool for facilitating efficiency in machine learning"
            ]
        },
        {
            "cluster_id": 3,
            "semantic_coherence": 0.393,
            "size": 155,
            "key_concepts": ["data", "model", "object", "second", "plurality", "image", "user"],
            "timeline": {
                "start_date": "2015-09-29",
                "end_date": "2022-11-21"
            },
            "unique_applicants": 12,
            "leading_applicants": [
                {"name": "INTEL CORP", "patents": 40, "percentage": 25.8},
                {"name": "AMAZON TECH INC", "patents": 27, "percentage": 17.4},
                {"name": "NVIDIA CORP", "patents": 19, "percentage": 12.3},
                {"name": "FORD GLOBAL TECH LLC", "patents": 19, "percentage": 12.3},
                {"name": "GOOGLE LLC", "patents": 19, "percentage": 12.3}
            ],
            "market_concentration": {
                "level": "Low",
                "hhi": 0.142
            },
            "top_cpc_symbols": [
                {"symbol": "G06N20/00", "count": 91},
                {"symbol": "G06N3/08", "count": 75},
                {"symbol": "G06N3/045", "count": 70}
            ],
            "example_patents": [
                "Identification of audio signals in surrounding sounds and guidance of an autonomous vehicle in response to the same",
                "Information processing apparatus, information processing method, and non-transitory storage medium"
            ]
        },
        {
            "cluster_id": 4,
            "semantic_coherence": 0.416,
            "size": 83,
            "key_concepts": ["circuit", "cooling", "second", "memory", "matrix", "processing", "apparatus"],
            "timeline": {
                "start_date": "2016-08-11",
                "end_date": "2022-06-28"
            },
            "unique_applicants": 5,
            "leading_applicants": [
                {"name": "INTEL CORP", "patents": 38, "percentage": 45.8},
                {"name": "NVIDIA CORP", "patents": 29, "percentage": 34.9},
                {"name": "QUALCOMM INC", "patents": 10, "percentage": 12.0},
                {"name": "AMAZON TECH INC", "patents": 5, "percentage": 6.0},
                {"name": "GOOGLE LLC", "patents": 1, "percentage": 1.2}
            ],
            "market_concentration": {
                "level": "High",
                "hhi": 0.350
            },
            "top_cpc_symbols": [
                {"symbol": "G06N3/063", "count": 53},
                {"symbol": "G06N3/045", "count": 51},
                {"symbol": "G06N3/08", "count": 42}
            ],
            "example_patents": [
                "Scalable edge computing",
                "Neural network accelerator using logarithmic-based arithmetic"
            ]
        },
        {
            "cluster_id": 5,
            "semantic_coherence": 0.470,
            "size": 197,
            "key_concepts": ["vehicle", "data", "driving", "sensor", "second", "method", "adv"],
            "timeline": {
                "start_date": "2014-12-05",
                "end_date": "2022-12-15"
            },
            "unique_applicants": 14,
            "leading_applicants": [
                {"name": "FORD GLOBAL TECH LLC", "patents": 56, "percentage": 28.4},
                {"name": "BAIDU USA LLC", "patents": 33, "percentage": 16.8},
                {"name": "TOYOTA RES INST INC", "patents": 33, "percentage": 16.8},
                {"name": "INTEL CORP", "patents": 28, "percentage": 14.2},
                {"name": "NVIDIA CORP", "patents": 14, "percentage": 7.1}
            ],
            "market_concentration": {
                "level": "Medium",
                "hhi": 0.162
            },
            "top_cpc_symbols": [
                {"symbol": "G06N20/00", "count": 110},
                {"symbol": "G06N3/08", "count": 106},
                {"symbol": "G06N3/045", "count": 64}
            ],
            "example_patents": [
                "Group driving style learning framework for autonomous vehicles",
                "Automatic navigation using deep reinforcement learning"
            ]
        }
    ],
    "cluster_analysis": {
        "coherence_stats": {
            "highest_coherence": {"cluster_id": [0, 5], "value": 0.470},
            "lowest_coherence": {"cluster_id": 3, "value": 0.393},
            "average_coherence": 0.440
        },
        "size_distribution": {
            "largest_cluster": {"cluster_id": 5, "size": 197},
            "smallest_cluster": {"cluster_id": 0, "size": 43},
            "average_cluster_size": 111.2
        },
        "market_concentration_distribution": {
            "high": [0, 4],
            "medium": [1, 2, 5],
            "low": [3]
        },
        "temporal_span": {
            "earliest_start": "2014-12-05",
            "latest_end": "2022-12-15",
            "total_timespan_years": 8.03
        }
    },
    "top_applicants_across_clusters": [
        {"name": "INTEL CORP", "total_patents": 140, "active_clusters": [0, 1, 2, 3, 4, 5]},
        {"name": "NVIDIA CORP", "total_patents": 128, "active_clusters": [1, 2, 3, 4, 5]},
        {"name": "QUALCOMM INC", "total_patents": 72, "active_clusters": [0, 1, 2, 4]},
        {"name": "FORD GLOBAL TECH LLC", "total_patents": 86, "active_clusters": [0, 1, 3, 5]},
        {"name": "AMAZON TECH INC", "total_patents": 37, "active_clusters": [2, 3, 4]}
    ]
}

# Save to JSON file
with open("semantic_clustering_report.json", "w", encoding="utf-8") as f:
    json.dump(semantic_clustering_report, f, indent=4)

print("Semantic clustering report saved to semantic_clustering_report.json")
# Out:
# Semantic clustering report saved to semantic_clustering_report.json

# %%
import json

innovation_outlier_report = {
    "report_title": "Innovation Outlier Detection Summary",
    "analysis_overview": {
        "total_patents_analyzed": 667,
        "outliers_detected": 100,
        "outlier_percentage": 14.99,
        "detection_methods": [
            "isolation_forest",
            "autoencoder", 
            "dbscan",
            "statistical",
            "ensemble"
        ]
    },
    "top_radical_innovations": [
        {
            "rank": 1,
            "title": "Video compression using recurrent-based machine learning sys...",
            "company": "QUALCOMM INC",
            "outlier_score": 0.7671,
            "technology": "Video Compression"
        },
        {
            "rank": 2,
            "title": "Dynamic uplink data split threshold...",
            "company": "QUALCOMM INC",
            "outlier_score": 0.6958,
            "technology": "Wireless Communication"
        },
        {
            "rank": 3,
            "title": "Radar-aided single image three-dimensional depth reconstruct...",
            "company": "QUALCOMM INC",
            "outlier_score": 0.6282,
            "technology": "Sensor Fusion for Depth Reconstruction"
        },
        {
            "rank": 4,
            "title": "Locally and globally locating actors by digital cameras and ...",
            "company": "AMAZON TECH INC",
            "outlier_score": 0.6134,
            "technology": "Computer Vision for Autonomous Vehicles"
        },
        {
            "rank": 5,
            "title": "Layout parasitics and device parameter prediction using grap...",
            "company": "NVIDIA CORP",
            "outlier_score": 0.5763,
            "technology": "Circuit Simulation and Design"
        }
    ],
    "strategic_pivots": {
        "total_companies_detected": 4,
        "companies": [
            {
                "company": "APPLE INC",
                "pivot_year": 2021,
                "outlier_rate_increase": 66.7,
                "recent_focus": [
                    "Natural Language Processing (NLP)",
                    "Autonomous Vehicle Perception"
                ]
            },
            {
                "company": "GOOGLE LLC",
                "pivot_year": 2022,
                "outlier_rate_increase": 37.5,
                "recent_focus": [
                    "Computer Vision",
                    "Human-Machine Interface (HMI)"
                ]
            },
            {
                "company": "AMAZON TECH INC",
                "pivot_year": 2024,
                "outlier_rate_increase": 33.3,
                "recent_focus": [
                    "Human-Machine Interface (HMI)",
                    "Autonomous Delivery Systems"
                ]
            }
        ]
    },
    "key_insights": {
        "most_innovative_producer": {
            "company": "NVIDIA CORP",
            "radical_innovations": 27
        },
        "top_technology_area": "ai_ml_architecture",
        "companies_with_strategic_pivots": [
            "APPLE INC",
            "GOOGLE LLC", 
            "AMAZON TECH INC"
        ],
        "peak_innovation_year": 2024,
        "novelty_description_factor": 1.01
    },
    "innovation_leaders": [
        {
            "rank": 1,
            "company": "NVIDIA CORP",
            "outlier_patents": 27,
            "outlier_rate": 21.1
        },
        {
            "rank": 2,
            "company": "INTEL CORP",
            "outlier_patents": 15,
            "outlier_rate": 10.7
        },
        {
            "rank": 3,
            "company": "QUALCOMM INC",
            "outlier_patents": 13,
            "outlier_rate": 16.5
        },
        {
            "rank": 4,
            "company": "FORD GLOBAL TECH LLC",
            "outlier_patents": 11,
            "outlier_rate": 12.2
        },
        {
            "rank": 5,
            "company": "AMAZON TECH INC",
            "outlier_patents": 11,
            "outlier_rate": 23.4
        }
    ],
    "analysis_statistics": {
        "outlier_score_stats": {
            "highest_score": 0.7671,
            "lowest_top5_score": 0.5763,
            "average_top5_score": 0.6362
        },
        "company_distribution": {
            "qualcomm_dominance_in_top5": 3,
            "total_companies_in_top5": 3,
            "most_diverse_technologies": "QUALCOMM INC"
        },
        "pivot_analysis": {
            "average_pivot_increase": 45.8,
            "most_recent_pivot_year": 2024,
            "earliest_pivot_year": 2021,
            "pivot_timespan_years": 3
        },
        "innovation_metrics": {
            "total_innovation_leaders": 5,
            "highest_outlier_rate": 23.4,
            "lowest_outlier_rate": 10.7,
            "average_outlier_rate": 16.78
        }
    },
    "technology_breakdown": {
        "represented_technologies": [
            "Video Compression",
            "Wireless Communication", 
            "Sensor Fusion for Depth Reconstruction",
            "Computer Vision for Autonomous Vehicles",
            "Circuit Simulation and Design",
            "Natural Language Processing (NLP)",
            "Autonomous Vehicle Perception",
            "Human-Machine Interface (HMI)",
            "Autonomous Delivery Systems"
        ],
        "dominant_focus_areas": [
            "ai_ml_architecture",
            "Computer Vision",
            "Human-Machine Interface (HMI)",
            "Autonomous Vehicle Technologies"
        ]
    }
}

# Save to JSON file
with open("innovation_outlier_report.json", "w", encoding="utf-8") as f:
    json.dump(innovation_outlier_report, f, indent=4)

print("Innovation outlier detection report saved to innovation_outlier_report.json")
# Out:
# Innovation outlier detection report saved to innovation_outlier_report.json

# %%
import json

technology_emergence_report = {
    "report_title": "Technology Emergence Analysis Report",
    "analysis_overview": {
        "total_technologies_analyzed": 15,
        "top_technologies_by_patent_count": 10,
        "top_emerging_technologies": 10
    },
    "patent_count_rankings": [
        {"rank": 1, "technology": "ai_ml_architecture", "patent_count": 574},
        {"rank": 2, "technology": "data_processing", "patent_count": 563},
        {"rank": 3, "technology": "software_algorithms", "patent_count": 349},
        {"rank": 4, "technology": "perception_sensing", "patent_count": 266},
        {"rank": 5, "technology": "vehicle_control_systems", "patent_count": 222},
        {"rank": 6, "technology": "hardware_sensors", "patent_count": 169},
        {"rank": 7, "technology": "path_planning_control", "patent_count": 117},
        {"rank": 8, "technology": "simulation_testing", "patent_count": 113},
        {"rank": 9, "technology": "v2x_communication", "patent_count": 94},
        {"rank": 10, "technology": "human_machine_interface", "patent_count": 92}
    ],
    "emergence_analysis": {
        "total_technologies_scored": 15,
        "emerging_technologies_ranking": [
            {
                "rank": 1,
                "technology": "perception_sensing",
                "emergence_score": 0.679777,
                "growth_rate": 1.410256
            },
            {
                "rank": 2,
                "technology": "data_processing",
                "emergence_score": 0.673646,
                "growth_rate": 1.139665
            },
            {
                "rank": 3,
                "technology": "v2x_communication",
                "emergence_score": 0.666943,
                "growth_rate": 4.200000
            },
            {
                "rank": 4,
                "technology": "software_algorithms",
                "emergence_score": 0.665077,
                "growth_rate": 1.163636
            },
            {
                "rank": 5,
                "technology": "ai_ml_architecture",
                "emergence_score": 0.655254,
                "growth_rate": 0.893939
            },
            {
                "rank": 6,
                "technology": "other",
                "emergence_score": 0.651886,
                "growth_rate": 5.000000
            },
            {
                "rank": 7,
                "technology": "human_machine_interface",
                "emergence_score": 0.633157,
                "growth_rate": 1.407407
            },
            {
                "rank": 8,
                "technology": "cybersecurity",
                "emergence_score": 0.600084,
                "growth_rate": 2.500000
            },
            {
                "rank": 9,
                "technology": "hardware_sensors",
                "emergence_score": 0.599542,
                "growth_rate": 1.017857
            },
            {
                "rank": 10,
                "technology": "localization_mapping",
                "emergence_score": 0.583016,
                "growth_rate": 1.571429
            }
        ]
    },
    "key_insights": {
        "highest_emergence_score": {
            "technology": "perception_sensing",
            "score": 0.679777
        },
        "highest_growth_rate": {
            "technology": "other",
            "rate": 5.000000
        },
        "most_patented_technology": {
            "technology": "ai_ml_architecture",
            "patent_count": 574
        },
        "fastest_growing_established_tech": {
            "technology": "v2x_communication",
            "growth_rate": 4.200000,
            "emergence_score": 0.666943
        }
    },
    "analysis_statistics": {
        "emergence_scores": {
            "highest": 0.679777,
            "lowest_in_top10": 0.583016,
            "average_top10": 0.635438,
            "score_range": 0.096761
        },
        "growth_rates": {
            "highest": 5.000000,
            "lowest_in_top10": 0.893939,
            "average_top10": 2.138389,
            "most_stable_growth": {
                "technology": "ai_ml_architecture",
                "rate": 0.893939
            }
        },
        "patent_distribution": {
            "total_patents_top10": 2459,
            "largest_category_share": {
                "technology": "ai_ml_architecture",
                "percentage": 23.3
            },
            "smallest_category_share": {
                "technology": "human_machine_interface",
                "percentage": 3.7
            }
        }
    },
    "technology_categories": {
        "core_ai_ml": ["ai_ml_architecture", "data_processing", "software_algorithms"],
        "sensing_perception": ["perception_sensing", "hardware_sensors", "localization_mapping"],
        "vehicle_systems": ["vehicle_control_systems", "path_planning_control"],
        "communication_interface": ["v2x_communication", "human_machine_interface"],
        "supporting_technologies": ["simulation_testing", "cybersecurity", "other"]
    },
    "emergence_insights": {
        "breakthrough_technologies": [
            {
                "technology": "v2x_communication",
                "reason": "High growth rate (4.2x) with strong emergence score"
            },
            {
                "technology": "perception_sensing", 
                "reason": "Highest emergence score with solid growth"
            }
        ],
        "mature_but_evolving": [
            {
                "technology": "ai_ml_architecture",
                "reason": "Highest patent count but moderate growth, indicating maturation"
            }
        ],
        "niche_but_growing": [
            {
                "technology": "cybersecurity",
                "reason": "Lower patent volume but high growth rate (2.5x)"
            }
        ]
    }
}

# Save to JSON file
with open("technology_emergence_report.json", "w", encoding="utf-8") as f:
    json.dump(technology_emergence_report, f, indent=4)

print("Technology emergence analysis report saved to technology_emergence_report.json")
# Out:
# Technology emergence analysis report saved to technology_emergence_report.json
